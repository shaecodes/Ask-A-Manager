# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the Data

# %%
df = pd.read_csv('askamanager.csv')
df
# Out:
#                 Timestamp How old are you?  What industry do you work in?
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)  \
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 27955   4/17/2023 9:40:21            18-24           Hospitality & Events
# 27956   4/18/2023 9:26:31            35-44              Computing or Tech
# 27957  4/21/2023 10:22:45            25-34                 Research / Gov
# 27958  4/24/2023 19:45:01            25-34  Accounting, Banking & Finance
# 27959  4/29/2023 15:24:07            18-24   Engineering or Manufacturing
#
#                                       Job title
# 0            Research and Instruction Librarian  \
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 27955                                  Waitress
# 27956                             Porting Agent
# 27957                   Post-doctoral Associate
# 27958                               CRM Manager
# 27959                             Data Engineer
#
#       If your job title needs additional context, please clarify here:
# 0                                                    NaN                \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27955                                                NaN
# 27956     Port phone numbers from one carrier to another
# 27957                         Research Scientist at NASA
# 27958                                                NaN
# 27959                                                NaN
#
#       What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)
# 0                                                 55,000                                                                                                                                                                                    \
# 1                                                 54,600
# 2                                                 34,000
# 3                                                 62,000
# 4                                                 60,000
# ...                                                  ...
# 27955                                              35000
# 27956                                              60000
# 27957                                              83000
# 27958                                              57000
# 27959                                              10000
#
#        How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.
# 0                                                    0.0                                                                                                                                               \
# 1                                                 4000.0
# 2                                                    NaN
# 3                                                 3000.0
# 4                                                 7000.0
# ...                                                  ...
# 27955                                            10000.0
# 27956                                             5000.0
# 27957                                                NaN
# 27958                                                NaN
# 27959                                                NaN
#
#       Please indicate the currency
# 0                              USD  \
# 1                              GBP
# 2                              USD
# 3                              USD
# 4                              USD
# ...                            ...
# 27955                          USD
# 27956                          USD
# 27957                          USD
# 27958                          GBP
# 27959                        Other
#
#       If "Other," please indicate the currency here:
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 27955                                             NaN
# 27956                                             NaN
# 27957                                             NaN
# 27958                                             NaN
# 27959                                             NaN
#
#       If your income needs additional context, please provide it here:
# 0                                                    NaN                \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27955                                                NaN
# 27956                                                NaN
# 27957                                                NaN
# 27958                                                NaN
# 27959                                                NaN
#
#       What country do you work in?
# 0                    United States  \
# 1                   United Kingdom
# 2                               US
# 3                              USA
# 4                               US
# ...                            ...
# 27955                United States
# 27956                United States
# 27957               United States
# 27958                           UK
# 27959                        India
#
#       If you're in the U.S., what state do you work in?
# 0                                         Massachusetts  \
# 1                                                   NaN
# 2                                             Tennessee
# 3                                             Wisconsin
# 4                                        South Carolina
# ...                                                 ...
# 27955                                          New York
# 27956                                           Georgia
# 27957                              District of Columbia
# 27958                                               NaN
# 27959                                               NaN
#
#       What city do you work in?
# 0                        Boston  \
# 1                     Cambridge
# 2                   Chattanooga
# 3                     Milwaukee
# 4                    Greenville
# ...                         ...
# 27955                 Rochester
# 27956                   Atlanta
# 27957                        Dc
# 27958                    London
# 27959                  Banglore
#
#       How many years of professional work experience do you have overall?
# 0                                              5-7 years                   \
# 1                                           8 - 10 years
# 2                                            2 - 4 years
# 3                                           8 - 10 years
# 4                                           8 - 10 years
# ...                                                  ...
# 27955                                          5-7 years
# 27956                                      21 - 30 years
# 27957                                        2 - 4 years
# 27958                                          5-7 years
# 27959                                     1 year or less
#
#       How many years of professional work experience do you have in your field?
# 0                                              5-7 years                         \
# 1                                              5-7 years
# 2                                            2 - 4 years
# 3                                              5-7 years
# 4                                              5-7 years
# ...                                                  ...
# 27955                                        2 - 4 years
# 27956                                        2 - 4 years
# 27957                                        2 - 4 years
# 27958                                        2 - 4 years
# 27959                                     1 year or less
#
#       What is your highest level of education completed? What is your gender?
# 0                                        Master's degree                Woman  \
# 1                                         College degree           Non-binary
# 2                                         College degree                Woman
# 3                                         College degree                Woman
# 4                                         College degree                Woman
# ...                                                  ...                  ...
# 27955                                       Some college                Woman
# 27956                                       Some college                  Man
# 27957                                                PhD                  Man
# 27958                                       Some college                Woman
# 27959                                                NaN                  Man
#
#       What is your race? (Choose all that apply.)
# 0                                           White
# 1                                           White
# 2                                           White
# 3                                           White
# 4                                           White
# ...                                           ...
# 27955                                       White
# 27956         Hispanic, Latino, or Spanish origin
# 27957                                       White
# 27958                                       White
# 27959                     Asian or Asian American
#
# [27960 rows x 18 columns]

# %% [markdown]
# ## Getting Basic Info about the Data

# %%
df.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)  \
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title
# 0        Research and Instruction Librarian  \
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:
# 0                                                NaN                \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)
# 0                                             55,000                                                                                                                                                                                    \
# 1                                             54,600
# 2                                             34,000
# 3                                             62,000
# 4                                             60,000
#
#    How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.
# 0                                                0.0                                                                                                                                               \
# 1                                             4000.0
# 2                                                NaN
# 3                                             3000.0
# 4                                             7000.0
#
#   Please indicate the currency
# 0                          USD  \
# 1                          GBP
# 2                          USD
# 3                          USD
# 4                          USD
#
#   If "Other," please indicate the currency here:
# 0                                             NaN  \
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   If your income needs additional context, please provide it here:
# 0                                                NaN                \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What country do you work in?
# 0                United States  \
# 1               United Kingdom
# 2                           US
# 3                          USA
# 4                           US
#
#   If you're in the U.S., what state do you work in? What city do you work in?
# 0                                     Massachusetts                    Boston  \
# 1                                               NaN                 Cambridge
# 2                                         Tennessee               Chattanooga
# 3                                         Wisconsin                 Milwaukee
# 4                                    South Carolina                Greenville
#
#   How many years of professional work experience do you have overall?
# 0                                          5-7 years                   \
# 1                                       8 - 10 years
# 2                                        2 - 4 years
# 3                                       8 - 10 years
# 4                                       8 - 10 years
#
#   How many years of professional work experience do you have in your field?
# 0                                          5-7 years                         \
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
#
#   What is your highest level of education completed? What is your gender?
# 0                                    Master's degree                Woman  \
# 1                                     College degree           Non-binary
# 2                                     College degree                Woman
# 3                                     College degree                Woman
# 4                                     College degree                Woman
#
#   What is your race? (Choose all that apply.)
# 0                                       White
# 1                                       White
# 2                                       White
# 3                                       White
# 4                                       White

# %%
df.tail()
# Out:
#                 Timestamp How old are you?  What industry do you work in?
# 27955   4/17/2023 9:40:21            18-24           Hospitality & Events  \
# 27956   4/18/2023 9:26:31            35-44              Computing or Tech
# 27957  4/21/2023 10:22:45            25-34                 Research / Gov
# 27958  4/24/2023 19:45:01            25-34  Accounting, Banking & Finance
# 27959  4/29/2023 15:24:07            18-24   Engineering or Manufacturing
#
#                      Job title
# 27955                 Waitress  \
# 27956            Porting Agent
# 27957  Post-doctoral Associate
# 27958              CRM Manager
# 27959            Data Engineer
#
#       If your job title needs additional context, please clarify here:
# 27955                                                NaN                \
# 27956     Port phone numbers from one carrier to another
# 27957                         Research Scientist at NASA
# 27958                                                NaN
# 27959                                                NaN
#
#       What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)
# 27955                                              35000                                                                                                                                                                                    \
# 27956                                              60000
# 27957                                              83000
# 27958                                              57000
# 27959                                              10000
#
#        How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.
# 27955                                            10000.0                                                                                                                                               \
# 27956                                             5000.0
# 27957                                                NaN
# 27958                                                NaN
# 27959                                                NaN
#
#       Please indicate the currency
# 27955                          USD  \
# 27956                          USD
# 27957                          USD
# 27958                          GBP
# 27959                        Other
#
#       If "Other," please indicate the currency here:
# 27955                                             NaN  \
# 27956                                             NaN
# 27957                                             NaN
# 27958                                             NaN
# 27959                                             NaN
#
#       If your income needs additional context, please provide it here:
# 27955                                                NaN                \
# 27956                                                NaN
# 27957                                                NaN
# 27958                                                NaN
# 27959                                                NaN
#
#       What country do you work in?
# 27955                United States  \
# 27956                United States
# 27957               United States
# 27958                           UK
# 27959                        India
#
#       If you're in the U.S., what state do you work in?
# 27955                                          New York  \
# 27956                                           Georgia
# 27957                              District of Columbia
# 27958                                               NaN
# 27959                                               NaN
#
#       What city do you work in?
# 27955                 Rochester  \
# 27956                   Atlanta
# 27957                        Dc
# 27958                    London
# 27959                  Banglore
#
#       How many years of professional work experience do you have overall?
# 27955                                          5-7 years                   \
# 27956                                      21 - 30 years
# 27957                                        2 - 4 years
# 27958                                          5-7 years
# 27959                                     1 year or less
#
#       How many years of professional work experience do you have in your field?
# 27955                                        2 - 4 years                         \
# 27956                                        2 - 4 years
# 27957                                        2 - 4 years
# 27958                                        2 - 4 years
# 27959                                     1 year or less
#
#       What is your highest level of education completed? What is your gender?
# 27955                                       Some college                Woman  \
# 27956                                       Some college                  Man
# 27957                                                PhD                  Man
# 27958                                       Some college                Woman
# 27959                                                NaN                  Man
#
#       What is your race? (Choose all that apply.)
# 27955                                       White
# 27956         Hispanic, Latino, or Spanish origin
# 27957                                       White
# 27958                                       White
# 27959                     Asian or Asian American

# %%
print("Column datatypes: ")
print(df.dtypes)
# Out:
# Column datatypes:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# If your job title needs additional context, please clarify here:                                                                                                                                                                         object
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)     object
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          float64
# Please indicate the currency                                                                                                                                                                                                             object
# If "Other," please indicate the currency here:                                                                                                                                                                                           object
# If your income needs additional context, please provide it here:                                                                                                                                                                         object
# What country do you work in?                                                                                                                                                                                                             object
# If you're in the U.S., what state do you work in?                                                                                                                                                                                        object
# What city do you work in?                                                                                                                                                                                                                object
# How many years of professional work experience do you have overall?                                                                                                                                                                      object
# How many years of professional work experience do you have in your field?                                                                                                                                                                object
# What is your highest level of education completed?                                                                                                                                                                                       object
# What is your gender?                                                                                                                                                                                                                     object
# What is your race? (Choose all that apply.)                                                                                                                                                                                              object
# dtype: object

# %%
print("Missing values distrubution: ")
print(df.isnull().mean())
# Out:
# Missing values distrubution:
# Timestamp                                                                                                                                                                                                                               0.000000
# How old are you?                                                                                                                                                                                                                        0.000000
# What industry do you work in?                                                                                                                                                                                                           0.002575
# Job title                                                                                                                                                                                                                               0.000000
# If your job title needs additional context, please clarify here:                                                                                                                                                                        0.741202
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)    0.000000
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          0.259728
# Please indicate the currency                                                                                                                                                                                                            0.000000
# If "Other," please indicate the currency here:                                                                                                                                                                                          0.993026
# If your income needs additional context, please provide it here:                                                                                                                                                                        0.891488
# What country do you work in?                                                                                                                                                                                                            0.000000
# If you're in the U.S., what state do you work in?                                                                                                                                                                                       0.178326
# What city do you work in?                                                                                                                                                                                                               0.002825
# How many years of professional work experience do you have overall?                                                                                                                                                                     0.000000
# How many years of professional work experience do you have in your field?                                                                                                                                                               0.000000
# What is your highest level of education completed?                                                                                                                                                                                      0.007690
# What is your gender?                                                                                                                                                                                                                    0.005973
# What is your race? (Choose all that apply.)                                                                                                                                                                                             0.006044
# dtype: float64

# %%
print("All columns: ")
columns = list(df.columns)
columns
# Out:
# All columns:
# ['Timestamp',
#  'How old are you?',
#  'What industry do you work in?',
#  'Job title',
#  'If your job title needs additional context, please clarify here:',
#  "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)",
#  'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#  'Please indicate the currency',
#  'If "Other," please indicate the currency here: ',
#  'If your income needs additional context, please provide it here:',
#  'What country do you work in?',
#  "If you're in the U.S., what state do you work in?",
#  'What city do you work in?',
#  'How many years of professional work experience do you have overall?',
#  'How many years of professional work experience do you have in your field?',
#  'What is your highest level of education completed?',
#  'What is your gender?',
#  'What is your race? (Choose all that apply.)']

# %% [markdown]
# ## Cleaning the Data: Gender

# %% [markdown]
# ### Changing the values of Gender

# %%
df.dropna(subset=['What is your gender?'], inplace=True)

# %%
df['What is your gender?'] = df['What is your gender?'].replace(['Woman'],'Female')

# %%
df['What is your gender?'] = df['What is your gender?'].replace(['Man'],'Male')

# %% [markdown]
# ## Cleaning the Data: Country of Employment

# %% [markdown]
# ### Renaming the Columns of the Data

# %%
df.rename(columns={"How old are you?":"Age", "What industry do you work in?":"Industry","Job title": "Job Title", "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)":"Annual Salary"}, inplace = True )

# %%
df.rename(columns={"How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.":"Monetary Compensation"},inplace=True)

# %%
df.rename(columns={"Please indicate the currency":"Currency","What country do you work in?":"Country of Employment","If you're in the U.S., what state do you work in?":"State (USA)"}, inplace = True)

# %%
df.rename(columns={"How many years of professional work experience do you have overall?":"Overall Number of Years of Experience"}, inplace = True)

# %%
df.rename(columns={"How many years of professional work experience do you have in your field?":"Number of Years of Experience in Your Field"}, inplace = True)

# %%
df.rename(columns={"What is your highest level of education completed?":"Highest Level of Education", "What is your gender?":"Gender", "What is your race? (Choose all that apply.)":"Ethnicity"}, inplace = True)

# %% [markdown]
# ### Removing duplicate values

# %%
df.drop_duplicates()
# Out:
#                 Timestamp    Age                       Industry
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)  \
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 27955   4/17/2023 9:40:21  18-24           Hospitality & Events
# 27956   4/18/2023 9:26:31  35-44              Computing or Tech
# 27957  4/21/2023 10:22:45  25-34                 Research / Gov
# 27958  4/24/2023 19:45:01  25-34  Accounting, Banking & Finance
# 27959  4/29/2023 15:24:07  18-24   Engineering or Manufacturing
#
#                                       Job Title
# 0            Research and Instruction Librarian  \
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 27955                                  Waitress
# 27956                             Porting Agent
# 27957                   Post-doctoral Associate
# 27958                               CRM Manager
# 27959                             Data Engineer
#
#       If your job title needs additional context, please clarify here:
# 0                                                    NaN                \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27955                                                NaN
# 27956     Port phone numbers from one carrier to another
# 27957                         Research Scientist at NASA
# 27958                                                NaN
# 27959                                                NaN
#
#       Annual Salary  Monetary Compensation Currency
# 0            55,000                    0.0      USD  \
# 1            54,600                 4000.0      GBP
# 2            34,000                    NaN      USD
# 3            62,000                 3000.0      USD
# 4            60,000                 7000.0      USD
# ...             ...                    ...      ...
# 27955         35000                10000.0      USD
# 27956         60000                 5000.0      USD
# 27957         83000                    NaN      USD
# 27958         57000                    NaN      GBP
# 27959         10000                    NaN    Other
#
#       If "Other," please indicate the currency here:
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 27955                                             NaN
# 27956                                             NaN
# 27957                                             NaN
# 27958                                             NaN
# 27959                                             NaN
#
#       If your income needs additional context, please provide it here:
# 0                                                    NaN                \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27955                                                NaN
# 27956                                                NaN
# 27957                                                NaN
# 27958                                                NaN
# 27959                                                NaN
#
#       Country of Employment           State (USA) What city do you work in?
# 0             United States         Massachusetts                    Boston  \
# 1            United Kingdom                   NaN                 Cambridge
# 2                        US             Tennessee               Chattanooga
# 3                       USA             Wisconsin                 Milwaukee
# 4                        US        South Carolina                Greenville
# ...                     ...                   ...                       ...
# 27955         United States              New York                 Rochester
# 27956         United States               Georgia                   Atlanta
# 27957        United States   District of Columbia                        Dc
# 27958                    UK                   NaN                    London
# 27959                 India                   NaN                  Banglore
#
#       Overall Number of Years of Experience
# 0                                 5-7 years  \
# 1                              8 - 10 years
# 2                               2 - 4 years
# 3                              8 - 10 years
# 4                              8 - 10 years
# ...                                     ...
# 27955                             5-7 years
# 27956                         21 - 30 years
# 27957                           2 - 4 years
# 27958                             5-7 years
# 27959                        1 year or less
#
#       Number of Years of Experience in Your Field Highest Level of Education
# 0                                       5-7 years            Master's degree  \
# 1                                       5-7 years             College degree
# 2                                     2 - 4 years             College degree
# 3                                       5-7 years             College degree
# 4                                       5-7 years             College degree
# ...                                           ...                        ...
# 27955                                 2 - 4 years               Some college
# 27956                                 2 - 4 years               Some college
# 27957                                 2 - 4 years                        PhD
# 27958                                 2 - 4 years               Some college
# 27959                              1 year or less                        NaN
#
#            Gender                            Ethnicity
# 0          Female                                White
# 1      Non-binary                                White
# 2          Female                                White
# 3          Female                                White
# 4          Female                                White
# ...           ...                                  ...
# 27955      Female                                White
# 27956        Male  Hispanic, Latino, or Spanish origin
# 27957        Male                                White
# 27958      Female                                White
# 27959        Male              Asian or Asian American
#
# [27793 rows x 18 columns]

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df.drop(columns=['If your job title needs additional context, please clarify here:'], inplace=True)

# %%
df.drop(columns=['If your income needs additional context, please provide it here:'],inplace=True)

# %%
df.drop(columns=["Timestamp"], inplace=True)

# %%
df.drop(columns=['If "Other," please indicate the currency here: '],inplace=True)

# %%
df.drop(columns=['What city do you work in?'],inplace=True)

# %% [markdown]
# ### Removing inconsistency in the data

# %%
df['Country of Employment'] = df['Country of Employment'].replace([
    'USA', 
    'na', 
    'I work for a UAE-based organization, though I am personally in the US.',
    'usa ', 'USD', 'Unite States',  
    'The US', 
    'united states ', 
    'US of A', 'Usat', 
    'united states ', '🇺🇸 ', 
    'U. S ', 'U. S.', 'U.s.a.', 
    'United Sates of America', 
    'United Stares ', 'United Stares ', 
    'Unites States', 'United Statees', 
    'United STates', 'USaa' ,'uSA',' US',
    'Unites states ','UNited States', 'uS', 
    'United Stateds', 'USD' "USA, but for foreign gov't", 
    'United  States','United Statss','United States is America', 
    'USA tomorrow ',' U.S.', 'United Statws', 'UA', 'United States of American', 
    'US', 'The United States', "U.S.",'United States', 'Us ', 'U.SA', 
    'United States of america ', 'USA ', 'U.S>', 'ISA', 'United State', 
    'united states','usa', 'America', 'Uniteed States', 'U.s.', 
    ' United States', 'United Statesp', 'United Stattes', 'United Statea', 
    'United Statues', 'Untied States', 'United states of america', 
    'United Status', 'Unted States', 'Uniyed states', 'Uniyes States', 
    'United States of Americas', 'U.A.', 'I.S.', 'U.S.A ',
    'United States of America ','United States of American ', 
    'I am located in Canada but I work for a company in the US', 
    'United states', 'us', 'United States of America', 'United states ', 
    'Uniter Statez', 'United states of America', 'Unites States ', 
    'UNITED STATES', 'united States', 'United State of America', 'United Stated', 
    'Uniited States', 'United Sates', 'U.S.A. ', 'U.S', 'USA-- Virgin Islands', 
    'United States (I work from home and my clients are all over the US/Canada/PR', 
    'United States ', 'United statew', 'United y', 'U. S. ', 'US ', 
    'US govt employee overseas, country withheld', 
    "I work for an US based company but I'm from Argentina.", 
    'For the United States government, but posted overseas', 
    'San Francisco', 'United States Of America', 'USA','USS',
    'UXZ', 'USA', 'Us', 'USA', 'bonus based on meeting yearly goals set w/ my supervisor',
    'Hartford', 'Y','USA (company is based in a US territory, I work remote)', 'america', 
    'Worldwide (based in US but short term trips aroudn the world)', 'From Romania, but for an US based company', 
    "USA, but for foreign gov't", 'united stated', 'Unitef Stated', 'Unites kingdom ', 'Unitied States', 
    'UnitedStates', 'USAB', 'United States of america', 'United Sttes', 'United Stares', 
    'United states of America ', 'Usa', 'united states of america', 'U.S.A.', 'UsA', 'u.s.', 
    'U.S.A', 'U.S. ', 'Usa ','U.S.A. '],'USA')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(["I earn commission on sales. If I meet quota, I'm guaranteed another 16k min. Last year i earned an additional 27k. It's not uncommon for people in my space to earn 100k+ after commission. "],'USA')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(["We don't get raises, we get quarterly bonuses, but they periodically asses income in the area you work, so I got a raise because a 3rd party assessment showed I was paid too little for the area we were located"],'USA')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['I was brought in on this salary to help with the EHR and very quickly was promoted to current position but compensation was not altered. '], 'USA')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(
    [
        'Can', 
        'Canad', 
        'Csnada', 
        'Canada', 
        'canada', 
        'CANADA', 
        'CANADA ', 
        'Currently finance', 
        "$2,175.84/year is deducted for benefits", 
        'Policy', 
        'Canada ', 
        'Canada and USA', 
        'Canada, Ottawa, ontario', 
        'Canadw', 
        'Canadá', 
        'Canda'
    ], 'Canada'
)

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Brasil',
 'Brazil',
 'Brazil '],'Brazil')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Australi',
 'Australia',
 'Australia ',
 'Australian ','australia' ],'Australia')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['England',
 'England ',
 'England, Gb',
 'England, UK',
 'England, UK.',
 'England, United Kingdom',
 'England, United Kingdom ',
 'England/UK',
 'Englang', 'Great Britain',
 'Great Britain ','U.K',
 'U.K.',
 'U.K. ',
 'U.K. (northern England)', 'UK',
 'UK ',
 'UK (England)',
 'UK (Northern Ireland)',
 'UK for U.S. company',
 'UK, but for globally fully remote company',
 'UK, remote', 'United Kindom',
 'United Kingdom',
 'United Kingdom ',
 'United Kingdom (England)',
 'United Kingdom.',
 'United Kingdomk',
 'United kingdom',
 'United kingdom ','Uk',
 'Uk ', 'ENGLAND', 'uk',
 'united kingdom', 'england'],'England')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['ARGENTINA BUT MY ORG IS IN THAILAND',
    'Argentina'],'Argentina')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Danmark',
 'Denmark',
 'Denmark '],'Denmark')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['FRANCE','France',
 'France ', 'france'],'France')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Czech Republic',
 'Czech Republic ',
 'Czech republic',
 'Czechia', 'czech republic', 'europe'],'Czech Republic')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Austria',
 'Austria, but I work remotely for a Dutch/British company'],'Austria')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['New Zealand',
 'New Zealand ',
 'New Zealand Aotearoa',
 'New zealand', 'new zealand', ' New Zealand', 'NZ','Aotearoa New Zealand', 'From New Zealand but on projects across APAC'],'New Zealand')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Northern Ireland',
 'Northern Ireland ',
 'Northern Ireland, United Kingdom', 'Ireland',
 'Ireland ', 'ireland'],'Ireland')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['The Netherlands',
 'The Netherlands ',
 'The netherlands', 'Nederland',
 'Netherlands',
 'Netherlands ', 'the Netherlands',
 'the netherlands', 'netherlands', 'NL'],'The Netherlands')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Bangladesh',
 'Bangladesh '],'Bangladesh')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Belgium',
 'Belgium '],'Belgium')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Company in Germany. I work from Pakistan.','germany','Germany',
 'Germany ' ],'Argentina')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Hong Kong',
 'Hong Kong '],'Hong Kong')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Japan','japan',
 'Japan ',
 'Japan, US Gov position',],'Japan')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Italy',
 'Italy (South)'],'Italy')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Luxembourg',
 'Luxemburg'],'Luxembourg')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Mexico',
 'Mexico ',
 'México'],'Mexico')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Mainland China'],'China')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['United States- Puerto Rico', 'Puerto Rico',
 'Puerto Rico '],'Puerto Rico')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Malaysia',
 'Malaysia '],'Malaysia')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Portugal',
 'Portugal '],'Portugal')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Wales',
 'Wales (UK)',
 'Wales (United Kingdom)',
 'Wales, UK'],'Wales')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['NIGERIA','Nigeria'],'Nigeria')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Remote',
 'Remote (philippines)', 'n/a (remote from wherever I want)'],'Philipines')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['SWITZERLAND','Switzerland',
 'Switzerland ', 'switzerland'],'Argentina')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Scotland',
 'Scotland ',
 'Scotland, UK'],'Scotland')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Norway',
 'Norway '],'Norway')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['South Africa',
 'South Africa ', 'South africa'],'Argentina')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Philippines',
 'Phillipines', 'Philipines',
 'Phillipines'],'Phillipines')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['South Korea',
 'South Korea '],'South Korea')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Spain',
 'Spain ', 'spain'],'Spain')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Singapore',
 'Singapore ', 'singapore'],'Singapore')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Sri Lanka',
 'Sri lanka'],'Sri Lanka')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['INDIA'],'India')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Jersey, Channel islands'],'Jersey')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['hong konh'],'Hong Kong')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['croatia', 'Croatia',
 'Croatia '],'Croatia')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['denmark'],'Denmark')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['finland'],'Finland')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['UAE', "United Arab Emirates "],'United Arab Emirates')

# %%
df['Country of Employment'] = df['Country of Employment'].replace(['Poland',
 'Poland '],'Poland')

# %%
sorted(df['Country of Employment'].unique())
# Out:
# ['Afghanistan',
#  'Africa',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bangladesh',
#  'Belgium',
#  'Bermuda',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Britain ',
#  'Bulgaria',
#  'California ',
#  'Cambodia',
#  'Canada',
#  'Catalonia',
#  'Cayman Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Contracts',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'England',
#  'Eritrea',
#  'Estonia',
#  'Finland',
#  'France',
#  'Ghana',
#  'Global',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'IS',
#  'India',
#  'Indonesia',
#  'International ',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kenya',
#  'Kuwait',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Morocco',
#  'New Zealand',
#  'Nigeria',
#  'Norway',
#  'Pakistan',
#  'Panamá',
#  'Phillipines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Romania',
#  'Russia ',
#  'Rwanda',
#  'Saudi Arabia',
#  'Scotland',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Somalia',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sweden',
#  'Sweden ',
#  'Taiwan',
#  'Thailand',
#  'The Bahamas ',
#  'The Netherlands',
#  'Trinidad and Tobago',
#  'Turkey',
#  'USA',
#  'Uganda',
#  'Ukraine ',
#  'United Arab Emirates',
#  'Uruguay',
#  'Vietnam',
#  'Virginia',
#  'Wales',
#  'Zimbabwe']

# %%
df
# Out:
#          Age                       Industry
# 0      25-34   Education (Higher Education)  \
# 1      25-34              Computing or Tech
# 2      25-34  Accounting, Banking & Finance
# 3      25-34                     Nonprofits
# 4      25-34  Accounting, Banking & Finance
# ...      ...                            ...
# 27955  18-24           Hospitality & Events
# 27956  35-44              Computing or Tech
# 27957  25-34                 Research / Gov
# 27958  25-34  Accounting, Banking & Finance
# 27959  18-24   Engineering or Manufacturing
#
#                                       Job Title Annual Salary
# 0            Research and Instruction Librarian        55,000  \
# 1      Change & Internal Communications Manager        54,600
# 2                          Marketing Specialist        34,000
# 3                               Program Manager        62,000
# 4                            Accounting Manager        60,000
# ...                                         ...           ...
# 27955                                  Waitress         35000
# 27956                             Porting Agent         60000
# 27957                   Post-doctoral Associate         83000
# 27958                               CRM Manager         57000
# 27959                             Data Engineer         10000
#
#        Monetary Compensation Currency Country of Employment
# 0                        0.0      USD                   USA  \
# 1                     4000.0      GBP               England
# 2                        NaN      USD                   USA
# 3                     3000.0      USD                   USA
# 4                     7000.0      USD                   USA
# ...                      ...      ...                   ...
# 27955                10000.0      USD                   USA
# 27956                 5000.0      USD                   USA
# 27957                    NaN      USD                   USA
# 27958                    NaN      GBP               England
# 27959                    NaN    Other                 India
#
#                 State (USA) Overall Number of Years of Experience
# 0             Massachusetts                             5-7 years  \
# 1                       NaN                          8 - 10 years
# 2                 Tennessee                           2 - 4 years
# 3                 Wisconsin                          8 - 10 years
# 4            South Carolina                          8 - 10 years
# ...                     ...                                   ...
# 27955              New York                             5-7 years
# 27956               Georgia                         21 - 30 years
# 27957  District of Columbia                           2 - 4 years
# 27958                   NaN                             5-7 years
# 27959                   NaN                        1 year or less
#
#       Number of Years of Experience in Your Field Highest Level of Education
# 0                                       5-7 years            Master's degree  \
# 1                                       5-7 years             College degree
# 2                                     2 - 4 years             College degree
# 3                                       5-7 years             College degree
# 4                                       5-7 years             College degree
# ...                                           ...                        ...
# 27955                                 2 - 4 years               Some college
# 27956                                 2 - 4 years               Some college
# 27957                                 2 - 4 years                        PhD
# 27958                                 2 - 4 years               Some college
# 27959                              1 year or less                        NaN
#
#            Gender                            Ethnicity
# 0          Female                                White
# 1      Non-binary                                White
# 2          Female                                White
# 3          Female                                White
# 4          Female                                White
# ...           ...                                  ...
# 27955      Female                                White
# 27956        Male  Hispanic, Latino, or Spanish origin
# 27957        Male                                White
# 27958      Female                                White
# 27959        Male              Asian or Asian American
#
# [27793 rows x 13 columns]

# %% [markdown]
# ## Cleaning the Data: Ethnicity

# %%
print("Missing values distrubution: ")
print(df.isnull().mean())
# Out:
# Missing values distrubution:
# Age                                            0.000000
# Industry                                       0.002555
# Job Title                                      0.000000
# Annual Salary                                  0.000000
# Monetary Compensation                          0.259094
# Currency                                       0.000000
# Country of Employment                          0.000000
# State (USA)                                    0.178066
# Overall Number of Years of Experience          0.000000
# Number of Years of Experience in Your Field    0.000000
# Highest Level of Education                     0.006369
# Gender                                         0.000000
# Ethnicity                                      0.004102
# dtype: float64

# %%
df['Ethnicity'].unique()
# Out:
# array(['White', 'Hispanic, Latino, or Spanish origin, White',
#        'Asian or Asian American, White', 'Asian or Asian American',
#        'Another option not listed here or prefer not to answer',
#        'Hispanic, Latino, or Spanish origin',
#        'Middle Eastern or Northern African',
#        'Hispanic, Latino, or Spanish origin, Middle Eastern or Northern African, White',
#        'Black or African American', 'Black or African American, White',
#        nan,
#        'Black or African American, Hispanic, Latino, or Spanish origin, White',
#        'Native American or Alaska Native',
#        'Native American or Alaska Native, White',
#        'Hispanic, Latino, or Spanish origin, Another option not listed here or prefer not to answer',
#        'Black or African American, Middle Eastern or Northern African, Native American or Alaska Native, White',
#        'White, Another option not listed here or prefer not to answer',
#        'Black or African American, Native American or Alaska Native, White',
#        'Asian or Asian American, Another option not listed here or prefer not to answer',
#        'Middle Eastern or Northern African, White',
#        'Asian or Asian American, Black or African American, White',
#        'Black or African American, Hispanic, Latino, or Spanish origin',
#        'Asian or Asian American, Black or African American',
#        'Asian or Asian American, Hispanic, Latino, or Spanish origin, White',
#        'Native American or Alaska Native, White, Another option not listed here or prefer not to answer',
#        'Asian or Asian American, Hispanic, Latino, or Spanish origin',
#        'Asian or Asian American, Native American or Alaska Native, White',
#        'Hispanic, Latino, or Spanish origin, Native American or Alaska Native',
#        'Black or African American, Middle Eastern or Northern African, White',
#        'Black or African American, Hispanic, Latino, or Spanish origin, Native American or Alaska Native, White',
#        'Black or African American, Another option not listed here or prefer not to answer',
#        'Native American or Alaska Native, Another option not listed here or prefer not to answer',
#        'Asian or Asian American, White, Another option not listed here or prefer not to answer',
#        'Asian or Asian American, Middle Eastern or Northern African',
#        'Asian or Asian American, Hispanic, Latino, or Spanish origin, Native American or Alaska Native, White',
#        'Hispanic, Latino, or Spanish origin, Middle Eastern or Northern African',
#        'Hispanic, Latino, or Spanish origin, Native American or Alaska Native, White',
#        'Middle Eastern or Northern African, White, Another option not listed here or prefer not to answer',
#        'Hispanic, Latino, or Spanish origin, White, Another option not listed here or prefer not to answer',
#        'Asian or Asian American, Black or African American, Hispanic, Latino, or Spanish origin',
#        'Asian or Asian American, Black or African American, Native American or Alaska Native, White',
#        'Middle Eastern or Northern African, Native American or Alaska Native, White',
#        'Asian or Asian American, Middle Eastern or Northern African, White',
#        'Black or African American, Middle Eastern or Northern African',
#        'Hispanic, Latino, or Spanish origin, Native American or Alaska Native, Another option not listed here or prefer not to answer',
#        'Asian or Asian American, Native American or Alaska Native',
#        'Middle Eastern or Northern African, Native American or Alaska Native',
#        'Asian or Asian American, Hispanic, Latino, or Spanish origin, Another option not listed here or prefer not to answer',
#        'Asian or Asian American, Hispanic, Latino, or Spanish origin, White, Another option not listed here or prefer not to answer'],
#       dtype=object)

# %%
df.dropna(subset=['Ethnicity'], inplace=True)

# %%
black_descent = df.loc[df['Ethnicity'].str.contains("Black", case=False)]
asian_descent = df.loc[df['Ethnicity'].str.contains("Asian", case=False)]
mena_descent = df.loc[df['Ethnicity'].str.contains("Eastern", case=False)]
native_descent = df.loc[df['Ethnicity'].str.contains("Native", case=False)]
spanish_descent = df.loc[df['Ethnicity'].str.contains("Spanish", case=False)]
white = df.loc[df['Ethnicity'].str.contains("White", case=False)]

# %%
black_count = len(black_descent)
asian_count = len(asian_descent)
mena_count = len(mena_descent)
native_count = len(native_descent)
spanish_count = len(spanish_descent)
white_count = len(white)

colors = sns.color_palette("pastel")

sns.barplot(x=['Black', 'Asian', 'MENA', 'Native', 'Spanish', 'White'], y=[black_count, asian_count, mena_count, native_count, spanish_count, white_count], palette=colors)
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.title('Count of Rows by Ethnicity')
plt.show()

# %% [markdown]
# ## Cleaning the Data: 'Highest Level of Education

# %%
df.dropna(subset=['Highest Level of Education'], inplace=True)

# %% [markdown]
# ## Cleaning the Data: Monetary Compensation

# %%
df.dropna(subset=['Monetary Compensation'], inplace=True)

# %% [markdown]
# ## Cleaning the Data: Country and State of Employment

# %%
in_the_us = ((df['Country of Employment'] == 'USA') & (df['State (USA)'].isnull()))
df.drop(index=df[in_the_us].index, inplace=True)

# %%
df.loc[(df['State (USA)'] != 'USA') & (df['State (USA)'].isnull()), 'State (USA)'] = 'Outside of the US'

# %%
df.head(50)
# Out:
#            Age                              Industry
# 0        25-34          Education (Higher Education)  \
# 1        25-34                     Computing or Tech
# 3        25-34                            Nonprofits
# 4        25-34         Accounting, Banking & Finance
# 6        25-34                            Publishing
# 8        45-54                     Computing or Tech
# 9        35-44         Accounting, Banking & Finance
# 11       35-44          Education (Higher Education)
# 12       35-44         Accounting, Banking & Finance
# 15       35-44        Utilities & Telecommunications
# 16       35-44                Business or Consulting
# 18       35-44                Business or Consulting
# 20       25-34                           Health care
# 23       35-44  Government and Public Administration
# 25       35-44          Education (Higher Education)
# 27       35-44                                   Law
# 31       35-44                       Media & Digital
# 33       35-44         Accounting, Banking & Finance
# 35       35-44          Education (Higher Education)
# 36       18-24                       Media & Digital
# 37       25-34         Accounting, Banking & Finance
# 38       35-44  Government and Public Administration
# 39       25-34         Accounting, Banking & Finance
# 40       45-54          Engineering or Manufacturing
# 41       35-44           Marketing, Advertising & PR
# 42       25-34  Government and Public Administration
# 43       25-34                     Computing or Tech
# 44       25-34                     Computing or Tech
# 45       25-34                            Nonprofits
# 46       35-44                     Computing or Tech
# 47       35-44                     Computing or Tech
# 48       25-34          Engineering or Manufacturing
# 49       25-34                                Retail
# 51       25-34         Education (Primary/Secondary)
# 52       25-34           Marketing, Advertising & PR
# 53       35-44                     Computing or Tech
# 54       35-44                       Media & Digital
# 55       35-44          Engineering or Manufacturing
# 57       25-34                Business or Consulting
# 58       25-34                                   Law
# 59       35-44  Government and Public Administration
# 62  65 or over              Property or Construction
# 65       25-34          Education (Higher Education)
# 66       25-34                            Nonprofits
# 67       35-44                           Health care
# 68       25-34                     Computing or Tech
# 70       25-34  Government and Public Administration
# 72       25-34                             Insurance
# 75       35-44                            Nonprofits
# 77       35-44         Education (Primary/Secondary)
#
#                                             Job Title Annual Salary
# 0                  Research and Instruction Librarian        55,000  \
# 1            Change & Internal Communications Manager        54,600
# 3                                     Program Manager        62,000
# 4                                  Accounting Manager        60,000
# 6                                Publishing Assistant        33,000
# 8                                     Systems Analyst       112,000
# 9                                   Senior Accountant        45,000
# 11  Deputy Title IX Coordinator/ Assistant Directo...        62,000
# 12                    Manager of Information Services       100,000
# 15                  Quality And Compliance Specialist        24,000
# 16                                Executive Assistant        85,000
# 18                                     Senior Manager        98,000
# 20                            Data Programmer Analyst        74,000
# 23                                         Researcher        96,000
# 25                          Communications Specialist        60,000
# 27                         Bookkeeper/Billing Manager        48,000
# 31                                             Editor       125,000
# 33                                 Accounting Manager       110,000
# 35                                 Senior IRB Analyst        68,000
# 36                                           Reporter        41,000
# 37                              Senior Administrator         76,000
# 38                          Staff Services Manager II        78,000
# 39                                       Receptionist        37,000
# 40                                      Lead Engineer       100,000
# 41                                  Senior Copywriter        35,000
# 42    Manager of Data Integrity and Prospect Research        65,000
# 43                        Principal Software Engineer       187,500
# 44                               Intelligence Analyst       110,000
# 45                                    Project Manager        66,625
# 46                                   Mobile developer       144,600
# 47                            Product Design Director       200,850
# 48                             Engineering specialist       120,000
# 49                             Manager, Total Rewards        97,500
# 51               Science Teacher (Public High School)        53,000
# 52                       Senior Manager, Programmatic        95,000
# 53                 Managed Services Sales Coordinator        72,000
# 54                                             Editor        52,000
# 55                           Water Resources Engineer       106,000
# 57                                 Account Supervisor       100,500
# 58                                    Legal Secretary        33,200
# 59                                        Policy Lead        52,000
# 62                                    Safety Director       104,000
# 65                                Research Programmer        70,000
# 66     Manager, Natural Climate Solutions Development        84,000
# 67                                         AR Manager        53,000
# 68                               Technical specialist        34,000
# 70                         City Research Scientist II        87,000
# 72                                    Pricing Analyst        45,000
# 75                              Supervisory Archivist        71,000
# 77       High School Teacher at an independent school        75,000
#
#     Monetary Compensation Currency Country of Employment
# 0                     0.0      USD                   USA  \
# 1                  4000.0      GBP               England
# 3                  3000.0      USD                   USA
# 4                  7000.0      USD                   USA
# 6                  2000.0      USD                   USA
# 8                 10000.0      USD                   USA
# 9                     0.0      USD                   USA
# 11                    0.0      USD                   USA
# 12                    0.0      USD                   USA
# 15                  500.0      GBP               England
# 16                 5000.0      USD                   USA
# 18                 1000.0      USD                   USA
# 20                    0.0      USD                   USA
# 23                 1000.0      USD                   USA
# 25                    0.0      USD                   USA
# 27                 4000.0      USD                   USA
# 31                    0.0      USD                   USA
# 33                15000.0      USD                   USA
# 35                    0.0      USD                   USA
# 36                  100.0      USD                   USA
# 37                10000.0      USD                   USA
# 38                    0.0      USD                   USA
# 39                    0.0      USD                   USA
# 40                50000.0      USD                   USA
# 41                 6000.0      GBP               England
# 42                    0.0      USD                   USA
# 43                 5000.0      USD                   USA
# 44                20000.0      USD                   USA
# 45                 1500.0      USD                   USA
# 46                 2500.0      USD                   USA
# 47                40000.0      USD                   USA
# 48                 1500.0      CAD                Canada
# 49                10000.0      CAD                Canada
# 51                 1000.0      USD                   USA
# 52                10000.0      USD                   USA
# 53                 3000.0      USD                   USA
# 54                    0.0      CAD                Canada
# 55                    0.0      USD                   USA
# 57                 3000.0      USD                   USA
# 58                    0.0      USD                   USA
# 59                    0.0      GBP               England
# 62                25000.0      USD                   USA
# 65                    0.0      USD                   USA
# 66                 8400.0      USD                   USA
# 67                    0.0      USD                   USA
# 68                 2000.0      USD                   USA
# 70                    0.0      USD                   USA
# 72                 2000.0      GBP               England
# 75                    0.0      USD                   USA
# 77                    0.0      USD                   USA
#
#              State (USA) Overall Number of Years of Experience
# 0          Massachusetts                             5-7 years  \
# 1      Outside of the US                          8 - 10 years
# 3              Wisconsin                          8 - 10 years
# 4         South Carolina                          8 - 10 years
# 6         South Carolina                           2 - 4 years
# 8               Missouri                         21 - 30 years
# 9                Florida                         21 - 30 years
# 11          Pennsylvania                         11 - 20 years
# 12              Michigan                         11 - 20 years
# 15     Outside of the US                         11 - 20 years
# 16              Illinois                          8 - 10 years
# 18               Georgia                         11 - 20 years
# 20          Pennsylvania                             5-7 years
# 23                  Ohio                          8 - 10 years
# 25              Michigan                         11 - 20 years
# 27              Maryland                         11 - 20 years
# 31  District of Columbia                         11 - 20 years
# 33              Virginia                         21 - 30 years
# 35        North Carolina                             5-7 years
# 36              Michigan                           2 - 4 years
# 37              New York                             5-7 years
# 38            California                          8 - 10 years
# 39                 Texas                           2 - 4 years
# 40               Georgia                         21 - 30 years
# 41     Outside of the US                         11 - 20 years
# 42              Virginia                             5-7 years
# 43          Pennsylvania                          8 - 10 years
# 44              Virginia                          8 - 10 years
# 45         Massachusetts                          8 - 10 years
# 46         Massachusetts                             5-7 years
# 47        North Carolina                         11 - 20 years
# 48     Outside of the US                         11 - 20 years
# 49     Outside of the US                          8 - 10 years
# 51             Minnesota                             5-7 years
# 52              Illinois                          8 - 10 years
# 53              Michigan                         11 - 20 years
# 54     Outside of the US                         11 - 20 years
# 55         Massachusetts                         21 - 30 years
# 57  District of Columbia                         11 - 20 years
# 58            New Jersey                          8 - 10 years
# 59     Outside of the US                         11 - 20 years
# 62               Georgia                      41 years or more
# 65          Rhode Island                             5-7 years
# 66  District of Columbia                             5-7 years
# 67              Illinois                         21 - 30 years
# 68             Minnesota                             5-7 years
# 70              New York                             5-7 years
# 72     Outside of the US                             5-7 years
# 75              New York                         11 - 20 years
# 77               Georgia                         11 - 20 years
#
#    Number of Years of Experience in Your Field Highest Level of Education
# 0                                    5-7 years            Master's degree  \
# 1                                    5-7 years             College degree
# 3                                    5-7 years             College degree
# 4                                    5-7 years             College degree
# 6                                  2 - 4 years             College degree
# 8                                21 - 30 years             College degree
# 9                                21 - 30 years             College degree
# 11                                   5-7 years                        PhD
# 12                               11 - 20 years             College degree
# 15                                   5-7 years             College degree
# 16                                8 - 10 years               Some college
# 18                                 2 - 4 years            Master's degree
# 20                                   5-7 years            Master's degree
# 23                                 2 - 4 years                        PhD
# 25                              1 year or less            Master's degree
# 27                                 2 - 4 years             College degree
# 31                                8 - 10 years            Master's degree
# 33                               11 - 20 years             College degree
# 35                                 2 - 4 years            Master's degree
# 36                                 2 - 4 years             College degree
# 37                                 2 - 4 years             College degree
# 38                                   5-7 years            Master's degree
# 39                                 2 - 4 years             College degree
# 40                               21 - 30 years             College degree
# 41                               11 - 20 years             College degree
# 42                                   5-7 years             College degree
# 43                                   5-7 years             College degree
# 44                                8 - 10 years            Master's degree
# 45                                8 - 10 years             College degree
# 46                                   5-7 years                        PhD
# 47                               11 - 20 years             College degree
# 48                                8 - 10 years             College degree
# 49                                8 - 10 years             College degree
# 51                              1 year or less            Master's degree
# 52                                8 - 10 years             College degree
# 53                                   5-7 years            Master's degree
# 54                               11 - 20 years             College degree
# 55                               11 - 20 years            Master's degree
# 57                                   5-7 years             College degree
# 58                                 2 - 4 years               Some college
# 59                               11 - 20 years            Master's degree
# 62                               21 - 30 years             College degree
# 65                                 2 - 4 years            Master's degree
# 66                                   5-7 years            Master's degree
# 67                               11 - 20 years            Master's degree
# 68                                   5-7 years             College degree
# 70                                 2 - 4 years            Master's degree
# 72                                 2 - 4 years            Master's degree
# 75                                8 - 10 years            Master's degree
# 77                               11 - 20 years            Master's degree
#
#         Gender                                          Ethnicity
# 0       Female                                              White
# 1   Non-binary                                              White
# 3       Female                                              White
# 4       Female                                              White
# 6       Female                                              White
# 8       Female                                              White
# 9       Female         Hispanic, Latino, or Spanish origin, White
# 11      Female         Hispanic, Latino, or Spanish origin, White
# 12        Male                     Asian or Asian American, White
# 15        Male                                              White
# 16      Female                                              White
# 18      Female                                              White
# 20      Female                                              White
# 23      Female                            Asian or Asian American
# 25      Female                                              White
# 27      Female  Another option not listed here or prefer not t...
# 31      Female                                              White
# 33      Female                                              White
# 35      Female                                              White
# 36      Female                                              White
# 37      Female                                              White
# 38      Female                                              White
# 39      Female                                              White
# 40      Female                                              White
# 41      Female                                              White
# 42        Male                                              White
# 43      Female                                              White
# 44        Male                                              White
# 45      Female         Hispanic, Latino, or Spanish origin, White
# 46      Female                                              White
# 47      Female                                              White
# 48      Female                                              White
# 49      Female                                              White
# 51      Female                                              White
# 52      Female                                              White
# 53      Female                                              White
# 54      Female                            Asian or Asian American
# 55      Female                                              White
# 57      Female                                              White
# 58      Female                                              White
# 59      Female                                              White
# 62        Male                                              White
# 65  Non-binary                                              White
# 66      Female                                              White
# 67      Female                                              White
# 68      Female                                              White
# 70        Male                                              White
# 72      Female                                              White
# 75      Female                                              White
# 77      Female                                              White

# %% [markdown]
# ## Cleaning the Data: Industry

# %%
industry = df[(df['Industry'].isnull())]
industry
# Out:
#          Age Industry                              Job Title Annual Salary
# 360    45-54      NaN                       Proposal Manager        87,938  \
# 645    35-44      NaN                           Legal editor        82,000
# 2104   25-34      NaN                       Research Analyst        61,000
# 2108   25-34      NaN   Senior Regulatory Affairs Specialist        45,000
# 4678   18-24      NaN                            GIS Analyst        35,360
# 5704   55-64      NaN                 Director of Compliance        68,000
# 6655   35-44      NaN               Youth Services Librarian        39,800
# 7461   55-64      NaN                 Executive Assistant II        87,490
# 8549   18-24      NaN                     Office Supervisor         26,000
# 8804   35-44      NaN    Chief of Staff, Customer Experience       169,000
# 9114   35-44      NaN                          Veterinarian         50,000
# 9269   25-34      NaN               Lab Assistant (Level II)        43,000
# 9913   25-34      NaN                      Manager, strategy       120,000
# 11131  25-34      NaN             People Operations Manager        155,000
# 11240  25-34      NaN             VP of Finance & Operations       140,000
# 12386  35-44      NaN                        Office manager         32,400
# 14456  25-34      NaN         Senior Manager of Ops Strategy       147,000
# 16740  55-64      NaN                     Credit Supervisor        103,500
# 16800  25-34      NaN                     Operations Manager       150,000
# 19053  45-54      NaN                         Director of HR        87,509
# 19102  55-64      NaN                     Accounting manager        74,000
# 19271  45-54      NaN                       HR Generalist II        77,000
# 19654  25-34      NaN          Campaign and Program Manager         68,000
# 20230  45-54      NaN                               Director       180,000
# 20301  35-44      NaN                  Marketing Coordinator        34,000
# 20742  25-34      NaN                         Vendor Manager         65000
# 21714  35-44      NaN                       Business Analyst         47000
# 21734  45-54      NaN               Administrative Assistant         37400
# 21882  35-44      NaN                  Technical specialist          50000
# 22266  45-54      NaN                   Inventory Specialist         48000
# 22500  55-64      NaN                     Software engineer         140000
# 22602  35-44      NaN                Government Statistician        134000
# 22857  35-44      NaN                             QA manager         35500
# 22912  45-54      NaN                    Account management0         52000
# 24958  25-34      NaN                                Chemist         81000
# 25098  35-44      NaN  Cybersecurity senior risk specialist          98000
# 25139  25-34      NaN                Early childhood teacher         60000
# 26223  25-34      NaN                         supply Planner            65
# 26449  25-34      NaN           Digital Marketing Specialist         51000
# 26594  35-44      NaN                             IT Manager         85000
# 26790  35-44      NaN              People Operations Manager         90000
# 26970  25-34      NaN                              Archivist         25740
# 27051  25-34      NaN                Data Analytics Engineer        115000
# 27239  25-34      NaN                    Instructor/Operator         55000
# 27250  55-64      NaN                 Technician Automation          35000
# 27592  45-54      NaN                    Associate professor         80000
#
#        Monetary Compensation Currency Country of Employment
# 360                   4000.0      USD                   USA  \
# 645                   8200.0      USD                   USA
# 2104                  2000.0      USD                   USA
# 2108                  4500.0      EUR               Ireland
# 4678                  1556.0      USD                   USA
# 5704                  5000.0      USD                   USA
# 6655                     0.0      USD                   USA
# 7461                  3000.0      USD                   USA
# 8549                  1000.0      USD                   USA
# 8804                 90000.0      USD                   USA
# 9114                     0.0      USD                   USA
# 9269                     0.0      USD                   USA
# 9913                 12000.0      USD                   USA
# 11131                25000.0      USD                   USA
# 11240                15000.0      USD                   USA
# 12386                    0.0      EUR               Belgium
# 14456                22000.0      USD                   USA
# 16740                10350.0      USD                   USA
# 16800                    0.0      USD                   USA
# 19053                30000.0      USD                   USA
# 19102                 3000.0      USD                   USA
# 19271                    0.0      USD                   USA
# 19654                 2680.0      USD                   USA
# 20230                35000.0      CAD                Canada
# 20301                    0.0      USD                   USA
# 20742                10000.0      USD                   USA
# 21714                    0.0      USD                   USA
# 21734                 4000.0      USD                   USA
# 21882                 1500.0      EUR               Ireland
# 22266                 1000.0      USD                   USA
# 22500                    0.0      USD                   USA
# 22602                 1250.0      USD                   USA
# 22857                    0.0      GBP               England
# 22912                 9000.0      USD                   USA
# 24958                 3000.0      USD                   USA
# 25098                 1600.0      USD                   USA
# 25139                    0.0  AUD/NZD             Australia
# 26223                    0.0      USD                   USA
# 26449                 5000.0      USD                   USA
# 26594                 7500.0      USD                   USA
# 26790                    0.0      USD                   USA
# 26970                    0.0      USD                   USA
# 27051                11500.0      USD                   USA
# 27239                    0.0      USD                   USA
# 27250                    0.0      EUR               Ireland
# 27592                    0.0      USD                   USA
#
#                 State (USA) Overall Number of Years of Experience
# 360          North Carolina                         21 - 30 years  \
# 645                New York                         11 - 20 years
# 2104               Maryland                             5-7 years
# 2108      Outside of the US                           2 - 4 years
# 4678                Florida                           2 - 4 years
# 5704                   Ohio                         21 - 30 years
# 6655         North Carolina                         11 - 20 years
# 7461          Massachusetts                         31 - 40 years
# 8549               New York                             5-7 years
# 8804                 Oregon                         21 - 30 years
# 9114               Missouri                             5-7 years
# 9269             California                           2 - 4 years
# 9913                Georgia                          8 - 10 years
# 11131            California                             5-7 years
# 11240            Washington                         11 - 20 years
# 12386     Outside of the US                          8 - 10 years
# 14456            California                             5-7 years
# 16740              Delaware                         21 - 30 years
# 16800                Oregon                         11 - 20 years
# 19053             Tennessee                         11 - 20 years
# 19102        North Carolina                         21 - 30 years
# 19271            Washington                         21 - 30 years
# 19654  District of Columbia                             5-7 years
# 20230     Outside of the US                         21 - 30 years
# 20301          Pennsylvania                         11 - 20 years
# 20742                 Texas                             5-7 years
# 21714             Tennessee                         21 - 30 years
# 21734           Mississippi                         21 - 30 years
# 21882     Outside of the US                         11 - 20 years
# 22266              Illinois                         11 - 20 years
# 22500            New Jersey                         31 - 40 years
# 22602  District of Columbia                         11 - 20 years
# 22857     Outside of the US                         11 - 20 years
# 22912              Illinois                             5-7 years
# 24958            California                             5-7 years
# 25098              Arkansas                         11 - 20 years
# 25139     Outside of the US                        1 year or less
# 26223              Colorado                         11 - 20 years
# 26449  District of Columbia                           2 - 4 years
# 26594              Illinois                         11 - 20 years
# 26790              Illinois                         21 - 30 years
# 26970            Washington                             5-7 years
# 27051               Indiana                          8 - 10 years
# 27239             Wisconsin                          8 - 10 years
# 27250     Outside of the US                         31 - 40 years
# 27592         New Hampshire                         11 - 20 years
#
#       Number of Years of Experience in Your Field
# 360                                 11 - 20 years  \
# 645                                 11 - 20 years
# 2104                                    5-7 years
# 2108                                  2 - 4 years
# 4678                               1 year or less
# 5704                                21 - 30 years
# 6655                                11 - 20 years
# 7461                                31 - 40 years
# 8549                                  2 - 4 years
# 8804                                  2 - 4 years
# 9114                                    5-7 years
# 9269                               1 year or less
# 9913                                 8 - 10 years
# 11131                                 2 - 4 years
# 11240                               11 - 20 years
# 12386                                   5-7 years
# 14456                                   5-7 years
# 16740                               21 - 30 years
# 16800                                8 - 10 years
# 19053                                8 - 10 years
# 19102                                8 - 10 years
# 19271                               21 - 30 years
# 19654                                   5-7 years
# 20230                               11 - 20 years
# 20301                               11 - 20 years
# 20742                                   5-7 years
# 21714                                8 - 10 years
# 21734                                8 - 10 years
# 21882                               11 - 20 years
# 22266                                8 - 10 years
# 22500                               31 - 40 years
# 22602                               11 - 20 years
# 22857                               11 - 20 years
# 22912                                   5-7 years
# 24958                                   5-7 years
# 25098                                   5-7 years
# 25139                              1 year or less
# 26223                                 2 - 4 years
# 26449                              1 year or less
# 26594                               11 - 20 years
# 26790                                8 - 10 years
# 26970                                   5-7 years
# 27051                                 2 - 4 years
# 27239                                 2 - 4 years
# 27250                               31 - 40 years
# 27592                               11 - 20 years
#
#                Highest Level of Education                         Gender
# 360                        College degree                         Female  \
# 645                       Master's degree                         Female
# 2104                       College degree                         Female
# 2108                      Master's degree                         Female
# 4678                       College degree                         Female
# 5704                       College degree                         Female
# 6655                      Master's degree                         Female
# 7461                       College degree                         Female
# 8549                       College degree                         Female
# 8804                       College degree                         Female
# 9114   Professional degree (MD, JD, etc.)                         Female
# 9269                       College degree                         Female
# 9913                       College degree                         Female
# 11131                     Master's degree                         Female
# 11240                      College degree                           Male
# 12386                     Master's degree                         Female
# 14456                      College degree                         Female
# 16740                      College degree                         Female
# 16800                     Master's degree                         Female
# 19053                         High School                         Female
# 19102                      College degree                         Female
# 19271                         High School                         Female
# 19654                      College degree                         Female
# 20230                     Master's degree                         Female
# 20301                        Some college                         Female
# 20742                        Some college                         Female
# 21714                         High School                           Male
# 21734                        Some college                         Female
# 21882                     Master's degree                         Female
# 22266                        Some college                         Female
# 22500                     Master's degree                           Male
# 22602                     Master's degree                           Male
# 22857                      College degree                         Female
# 22912                        Some college                         Female
# 24958                                 PhD                         Female
# 25098                     Master's degree  Other or prefer not to answer
# 25139                      College degree                         Female
# 26223                        Some college                         Female
# 26449                      College degree                         Female
# 26594                     Master's degree                           Male
# 26790                      College degree                         Female
# 26970                      College degree                         Female
# 27051                     Master's degree                           Male
# 27239                      College degree                           Male
# 27250                     Master's degree                           Male
# 27592                                 PhD                         Female
#
#                                                Ethnicity
# 360                                                White
# 645                                                White
# 2104                                               White
# 2108                                               White
# 4678                                               White
# 5704                                               White
# 6655                                               White
# 7461                                               White
# 8549                                               White
# 8804                                               White
# 9114                                               White
# 9269          Hispanic, Latino, or Spanish origin, White
# 9913                                               White
# 11131                                              White
# 11240                                              White
# 12386                                              White
# 14456                            Asian or Asian American
# 16740                          Black or African American
# 16800                            Asian or Asian American
# 19053                Hispanic, Latino, or Spanish origin
# 19102                                              White
# 19271                                              White
# 19654                                              White
# 20230                            Asian or Asian American
# 20301                                              White
# 20742                Hispanic, Latino, or Spanish origin
# 21714                                              White
# 21734                                              White
# 21882                                              White
# 22266                                              White
# 22500                                              White
# 22602                                              White
# 22857                                              White
# 22912                                              White
# 24958                            Asian or Asian American
# 25098  Another option not listed here or prefer not t...
# 25139                                              White
# 26223                            Asian or Asian American
# 26449                                              White
# 26594                          Black or African American
# 26790                                              White
# 26970                                              White
# 27051                Hispanic, Latino, or Spanish origin
# 27239                                              White
# 27250                                              White
# 27592                                              White

# %%
df.dropna(subset=['Industry'], inplace=True)

# %%
print("Missing values distrubution: ")
print(df.isnull().mean())
# Out:
# Missing values distrubution:
# Age                                            0.0
# Industry                                       0.0
# Job Title                                      0.0
# Annual Salary                                  0.0
# Monetary Compensation                          0.0
# Currency                                       0.0
# Country of Employment                          0.0
# State (USA)                                    0.0
# Overall Number of Years of Experience          0.0
# Number of Years of Experience in Your Field    0.0
# Highest Level of Education                     0.0
# Gender                                         0.0
# Ethnicity                                      0.0
# dtype: float64

# %% [markdown]
# ## Cleaning the Data: Annual Salary

# %%
df['Annual Salary'] = df['Annual Salary'].str.replace(',', '').astype(int)

# %%
df['Annual Salary'] = df['Annual Salary'].astype(float)

# %%
df.head()
# Out:
#      Age                       Industry
# 0  25-34   Education (Higher Education)  \
# 1  25-34              Computing or Tech
# 3  25-34                     Nonprofits
# 4  25-34  Accounting, Banking & Finance
# 6  25-34                     Publishing
#
#                                   Job Title  Annual Salary
# 0        Research and Instruction Librarian        55000.0  \
# 1  Change & Internal Communications Manager        54600.0
# 3                           Program Manager        62000.0
# 4                        Accounting Manager        60000.0
# 6                      Publishing Assistant        33000.0
#
#    Monetary Compensation Currency Country of Employment        State (USA)
# 0                    0.0      USD                   USA      Massachusetts  \
# 1                 4000.0      GBP               England  Outside of the US
# 3                 3000.0      USD                   USA          Wisconsin
# 4                 7000.0      USD                   USA     South Carolina
# 6                 2000.0      USD                   USA     South Carolina
#
#   Overall Number of Years of Experience
# 0                             5-7 years  \
# 1                          8 - 10 years
# 3                          8 - 10 years
# 4                          8 - 10 years
# 6                           2 - 4 years
#
#   Number of Years of Experience in Your Field Highest Level of Education
# 0                                   5-7 years            Master's degree  \
# 1                                   5-7 years             College degree
# 3                                   5-7 years             College degree
# 4                                   5-7 years             College degree
# 6                                 2 - 4 years             College degree
#
#        Gender Ethnicity
# 0      Female     White
# 1  Non-binary     White
# 3      Female     White
# 4      Female     White
# 6      Female     White

# %%
# Out:
#          Age                       Industry
# 0      25-34   Education (Higher Education)  \
# 1      25-34              Computing or Tech
# 3      25-34                     Nonprofits
# 4      25-34  Accounting, Banking & Finance
# 6      25-34                     Publishing
# ...      ...                            ...
# 27951  35-44  Education (Primary/Secondary)
# 27953  25-34    Marketing, Advertising & PR
# 27954  35-44          Real Estate / Housing
# 27955  18-24           Hospitality & Events
# 27956  35-44              Computing or Tech
#
#                                       Job Title  Annual Salary
# 0            Research and Instruction Librarian          55000  \
# 1      Change & Internal Communications Manager          54600
# 3                               Program Manager          62000
# 4                            Accounting Manager          60000
# 6                          Publishing Assistant          33000
# ...                                         ...            ...
# 27951                                   Teacher         104000
# 27953                        WEB CONTENT WRITER          72500
# 27954                        Technical Director         113000
# 27955                                  Waitress          35000
# 27956                             Porting Agent          60000
#
#        Monetary Compensation Currency Country of Employment
# 0                        0.0      USD                   USA  \
# 1                     4000.0      GBP               England
# 3                     3000.0      USD                   USA
# 4                     7000.0      USD                   USA
# 6                     2000.0      USD                   USA
# ...                      ...      ...                   ...
# 27951                 2000.0  AUD/NZD             Australia
# 27953                 5000.0      USD                   USA
# 27954                    0.0      EUR             Argentina
# 27955                10000.0      USD                   USA
# 27956                 5000.0      USD                   USA
#
#              State (USA) Overall Number of Years of Experience
# 0          Massachusetts                             5-7 years  \
# 1      Outside of the US                          8 - 10 years
# 3              Wisconsin                          8 - 10 years
# 4         South Carolina                          8 - 10 years
# 6         South Carolina                           2 - 4 years
# ...                  ...                                   ...
# 27951  Outside of the US                             5-7 years
# 27953         California                         11 - 20 years
# 27954  Outside of the US                         11 - 20 years
# 27955           New York                             5-7 years
# 27956            Georgia                         21 - 30 years
#
#       Number of Years of Experience in Your Field Highest Level of Education
# 0                                       5-7 years            Master's degree  \
# 1                                       5-7 years             College degree
# 3                                       5-7 years             College degree
# 4                                       5-7 years             College degree
# 6                                     2 - 4 years             College degree
# ...                                           ...                        ...
# 27951                                   5-7 years             College degree
# 27953                                   5-7 years             College degree
# 27954                                8 - 10 years            Master's degree
# 27955                                 2 - 4 years               Some college
# 27956                                 2 - 4 years               Some college
#
#            Gender                            Ethnicity
# 0          Female                                White
# 1      Non-binary                                White
# 3          Female                                White
# 4          Female                                White
# 6          Female                                White
# ...           ...                                  ...
# 27951      Female                                White
# 27953      Female                                White
# 27954        Male                                White
# 27955      Female                                White
# 27956        Male  Hispanic, Latino, or Spanish origin
#
# [20269 rows x 13 columns]
